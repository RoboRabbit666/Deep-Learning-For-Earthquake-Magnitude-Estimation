# %% [markdown]
# Cell 1: Initial Setup with SeisBench Download

# %%
# -*- coding: utf-8 -*-
"""
This notebook processes the INSTANCE dataset to create event-based groupings
and prepares data files for 50 different random event-based splits.
And uses SeisBench to download INSTANCE dataset directly to avoid Google Drive quota issues.
"""

# Install and import required packages
# !pip install seisbench
# !pip install torch torchvision torchaudio
# !pip install h5py pandas tqdm matplotlib torchinfo seaborn

from google.colab import drive
import time
import os
import numpy as np
import pandas as pd
import h5py
from tqdm import tqdm
import torch
from collections import defaultdict
import random
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.signal
import seisbench.data as sbd

# Start time
start_time = time.time()

# Check for GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Mount Google Drive for output directory only
drive.mount('/content/drive')

# Set SeisBench to use local VM storage (not Google Drive) to avoid quota issues
os.environ['SEISBENCH_CACHE_ROOT'] = '/content/.seisbench'
print(f"SeisBench cache root: {os.environ['SEISBENCH_CACHE_ROOT']}")

# Download INSTANCE dataset using SeisBench
print("Downloading INSTANCE dataset using SeisBench...")
print("This will download to local VM storage, avoiding Google Drive quota issues...")
instance = sbd.InstanceCounts()

# # Define the paths to local data files
# metadata_path = "/content/drive/My Drive/INSTANCE_Dataset/metadata.csv"
# hdf5_path = "/content/drive/My Drive/INSTANCE_Dataset/waveforms.hdf5"

# Get paths to the downloaded files
instance_path = instance.path
metadata_path = os.path.join(instance_path, "metadata.csv")
hdf5_path = os.path.join(instance_path, "waveforms.hdf5")

# Output directory (still on Google Drive for results)
output_dir = "/content/drive/My Drive/2023-2024/UCL MSc in DSML/Term 3/MSc Project/Code/INSTANCE_Event_Based/Upper_Half_EpiDis"
os.makedirs(output_dir, exist_ok=True)

# Verify files exist
print(f"INSTANCE dataset path: {instance_path}")
print(f"Files in INSTANCE dataset folder:")
print(os.listdir(instance_path))

assert os.path.isfile(metadata_path), f"Metadata file not found at {metadata_path}"
assert os.path.isfile(hdf5_path), f"HDF5 file not found at {hdf5_path}"

print(f"Using SeisBench INSTANCE files:")
print(f"Metadata: {metadata_path}")
print(f"HDF5: {hdf5_path}")
print(f"Output directory: {output_dir}")
# Out:
# Requirement already satisfied: seisbench in /usr/local/lib/python3.12/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from seisbench) (2.0.2)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.12/dist-packages (from seisbench) (2.2.2)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.12/dist-packages (from seisbench) (3.14.0)
# Requirement already satisfied: obspy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from seisbench) (1.4.2)
# Requirement already satisfied: tqdm>=4.52 in /usr/local/lib/python3.12/dist-packages (from seisbench) (4.67.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from seisbench) (2.8.0+cpu)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.12/dist-packages (from seisbench) (1.16.1)
# Requirement already satisfied: nest_asyncio>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from seisbench) (1.6.0)
# Requirement already satisfied: bottleneck>=1.3 in /usr/local/lib/python3.12/dist-packages (from seisbench) (1.5.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from obspy>=1.3.1->seisbench) (3.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from obspy>=1.3.1->seisbench) (6.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from obspy>=1.3.1->seisbench) (75.2.0)
# Requirement already satisfied: sqlalchemy<2 in /usr/local/lib/python3.12/dist-packages (from obspy>=1.3.1->seisbench) (1.4.54)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from obspy>=1.3.1->seisbench) (5.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from obspy>=1.3.1->seisbench) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1->seisbench) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1->seisbench) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1->seisbench) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->seisbench) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->seisbench) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->seisbench) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->seisbench) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->seisbench) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->seisbench) (2025.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->obspy>=1.3.1->seisbench) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->seisbench) (1.17.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<2->obspy>=1.3.1->seisbench) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->seisbench) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->seisbench) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->obspy>=1.3.1->seisbench) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->obspy>=1.3.1->seisbench) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->obspy>=1.3.1->seisbench) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->obspy>=1.3.1->seisbench) (2025.8.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cpu)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (3.14.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from h5py) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# Using device: cpu
# Mounted at /content/drive
# SeisBench cache root: /content/.seisbench
# Downloading INSTANCE dataset using SeisBench...
# This will download to local VM storage, avoiding Google Drive quota issues...
# 2025-08-28 12:51:46,558 | seisbench | WARNING | Dataset InstanceCounts not in cache.
# WARNING:seisbench:Dataset InstanceCounts not in cache.
# 2025-08-28 12:51:46,559 | seisbench | WARNING | Trying to download preprocessed version from SeisBench repository.
# WARNING:seisbench:Trying to download preprocessed version from SeisBench repository.
# Downloading metadata: 100%|██████████| 1.12G/1.12G [00:44<00:00, 27.1MB/s]
# Downloading waveforms: 100%|██████████| 155G/155G [1:42:17<00:00, 27.2MB/s]
# 2025-08-28 14:35:29,044 | seisbench | WARNING | Output component order not specified, defaulting to 'ZNE'.
# WARNING:seisbench:Output component order not specified, defaulting to 'ZNE'.
# INSTANCE dataset path: /root/.seisbench/datasets/instancecounts
# Files in INSTANCE dataset folder:
# ['waveforms.hdf5', 'metadata.csv']
# Using SeisBench INSTANCE files:
# Metadata: /root/.seisbench/datasets/instancecounts/metadata.csv
# HDF5: /root/.seisbench/datasets/instancecounts/waveforms.hdf5
# Output directory: /content/drive/My Drive/2023-2024/UCL MSc in DSML/Term 3/MSc Project/Code/INSTANCE_Event_Based/Upper_Half_EpiDis

# %% [markdown]
# Cell 2: Data Loading and Initial Filtering

# %%
"""Cell 2: Data Loading and Initial Filtering"""

# Load and access the metadata from the CSV file
metadata = pd.read_csv(metadata_path, low_memory=False)
print(f"Initial number of metadata entries: {len(metadata)}")

# Ensure the 'source_origin_time' column is in datetime format
metadata['source_origin_time'] = pd.to_datetime(metadata['source_origin_time'])

# Sort by source_origin_time to ensure chronological order
metadata = metadata.sort_values(by='source_origin_time')

#================No need to filter by date from September 2018 onwards since we want all data================
# # Filter metadata for dates from September 2018 onwards
# from datetime import datetime, timezone
# start_date = datetime(2018, 9, 1, tzinfo=timezone.utc)
# metadata = metadata[metadata['source_origin_time'] >= start_date]
# print(f"Number of metadata entries from 1st September 2018 to 31st January 2020: {len(metadata)}")
#=============================================================================================================

# Plot the histogram of the earthquake magnitudes before filtering
plt.figure(figsize=(10, 6))
sns.histplot(metadata["source_magnitude"], bins=30, kde=True)
plt.xlabel('Magnitude', fontweight='bold', fontsize=14)
plt.ylabel('Number', fontweight='bold', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.grid(True)
max_magnitude = metadata["source_magnitude"].max()
min_magnitude = metadata["source_magnitude"].min()
plt.text(0.7*max_magnitude, plt.gca().get_ylim()[1]*0.8,
         f'Max: {max_magnitude:.2f} M\nMin: {min_magnitude:.2f} M',
         bbox=dict(facecolor='none', edgecolor='red', boxstyle='round,pad=1'), fontsize=14)
plt.tight_layout()
plt.show()

print(f"Number of metadata entries now: {len(metadata)}")
# Out:
# Initial number of metadata entries: 1159249
# Number of metadata entries now: 1159249

# %% [markdown]
# Cell 3: Apply Data Filtering Criteria

# %%
"""Cell 3: Apply Data Filtering Criteria"""

import copy

# Create a deep copy of the metadata
filtered_metadata = copy.deepcopy(metadata)

# Set sampling rate
filtered_metadata['trace_sampling_rate_hz'] = 100

# Adjusted filtering for INSTANCE dataset within 30s window
filters = [
    ('path_ep_distance_km <= 110', filtered_metadata.path_ep_distance_km <= 110),
    ('source_magnitude_type == ML', filtered_metadata.source_magnitude_type == 'ML'),
    ('trace_P_arrival_sample.notnull()', filtered_metadata.trace_P_arrival_sample.notnull()),
    ('path_travel_time_P_s.notnull()', filtered_metadata.path_travel_time_P_s.notnull()),
    ('path_travel_time_P_s > 0', filtered_metadata.path_travel_time_P_s > 0),
    ('path_ep_distance_km.notnull()', filtered_metadata.path_ep_distance_km.notnull()),
    ('path_ep_distance_km > 0', filtered_metadata.path_ep_distance_km > 0),
    ('source_depth_km.notnull()', filtered_metadata.source_depth_km.notnull()),
    ('source_magnitude.notnull()', filtered_metadata.source_magnitude.notnull()),
    ('path_backazimuth_deg.notnull()', filtered_metadata.path_backazimuth_deg.notnull()),
    ('path_backazimuth_deg > 0', filtered_metadata.path_backazimuth_deg > 0),
]

# Apply filters one by one and keep track of the data
for desc, filt in filters:
    filtered_metadata = filtered_metadata[filt]
    print(f"After filter '{desc}': {len(filtered_metadata)} entries")

# Ensure at least 30 seconds of data after P-arrival
filtered_metadata = filtered_metadata[filtered_metadata.trace_P_arrival_sample + filtered_metadata.trace_sampling_rate_hz * 30 <= filtered_metadata.trace_npts]
print(f"After ensuring 30s after P arrival: {len(filtered_metadata)} entries")

# Calculate time window statistics
filtered_metadata['window_start'] = filtered_metadata.trace_P_arrival_sample - filtered_metadata.trace_sampling_rate_hz * 5  # 5 seconds before P arrival
filtered_metadata['window_end'] = filtered_metadata.trace_P_arrival_sample + filtered_metadata.trace_sampling_rate_hz * 25  # 25 seconds after P arrival (total 30s window)

# Ensure window start is not negative
filtered_metadata = filtered_metadata[filtered_metadata.window_start >= 0]
print(f"After ensuring non-negative window start: {len(filtered_metadata)} entries")

print(f"\nFinal number of filtered metadata entries: {len(filtered_metadata)}")
# Out:
# After filter 'path_ep_distance_km <= 110': 1010113 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'source_magnitude_type == ML': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'trace_P_arrival_sample.notnull()': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'path_travel_time_P_s.notnull()': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'path_travel_time_P_s > 0': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'path_ep_distance_km.notnull()': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'path_ep_distance_km > 0': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'source_depth_km.notnull()': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'source_magnitude.notnull()': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'path_backazimuth_deg.notnull()': 979936 entries
# /tmp/ipython-input-3586823848.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_metadata = filtered_metadata[filt]
# After filter 'path_backazimuth_deg > 0': 979761 entries
# After ensuring 30s after P arrival: 979757 entries
# After ensuring non-negative window start: 979755 entries
#
# Final number of filtered metadata entries: 979755

# %% [markdown]
# Cell 4: Apply SNR Filter and Multi-Observations

# %%
"""Cell 4: Apply SNR Filter and Multi-Observations"""

# Process SNR
# Check if 'snr_db' column exists, if not, use appropriate column names from INSTANCE dataset
if 'snr_db' in filtered_metadata.columns:
    def string_convertor(dd):
        if isinstance(dd, str):
            dd2 = dd.split()
            SNR = []
            for d in dd2:
                if d not in ['[', ']']:
                    dL = d.split('[')
                    dR = d.split(']')
                    if len(dL) == 2:
                        dig = dL[1]
                    elif len(dR) == 2:
                        dig = dR[0]
                    elif len(dR) == 1 and len(dL) == 1:
                        dig = d
                    try:
                        dig = float(dig)
                    except Exception:
                        dig = None
                    SNR.append(dig)
            return np.mean([x for x in SNR if x is not None])
        else:
            return np.nan

    filtered_metadata['snr_db'] = filtered_metadata.snr_db.apply(string_convertor)
    filtered_metadata = filtered_metadata[filtered_metadata.snr_db >= 20]
else:
    # Use appropriate SNR columns from INSTANCE dataset
    snr_columns = ['trace_E_snr_db', 'trace_N_snr_db', 'trace_Z_snr_db']
    filtered_metadata['avg_snr_db'] = filtered_metadata[snr_columns].mean(axis=1)
    filtered_metadata = filtered_metadata[filtered_metadata.avg_snr_db >= 20]

print(f"Number of records after SNR filtering: {len(filtered_metadata)}")

# Implementing multi-observations with a threshold of >= 400
print("Filtering for multi-observations stations...")
uniq_ins = filtered_metadata.station_code.unique()
labM = []

print("Counting observations per station...")
for station in tqdm(uniq_ins):
    count = sum(filtered_metadata.station_code == station)
    if count >= 400:
        labM.append(station)
        print(f"{station}: {count} observations")

print(f"Number of stations with ≥400 observations: {len(labM)}")

# Save the multi-observations stations list
multi_observations_path = os.path.join(output_dir, "multi_observations.npy")
np.save(multi_observations_path, labM)

# Filter the dataset to include only records from stations with ≥400 observations
df_filtered = filtered_metadata[filtered_metadata.station_code.isin(labM)]
print(f"Number of records after multi-observations filtering: {len(df_filtered)}")

# ADDED: Apply distance filter for upper split
df_filtered = df_filtered[df_filtered.path_ep_distance_km > 28.07]
print(f"Number of records after distance filtering (>28.07 km): {len(df_filtered)}")
# Out:
# Number of records after SNR filtering: 407164
# Filtering for multi-observations stations...
# Counting observations per station...
#   1%|          | 4/594 [00:00<00:29, 19.88it/s]
# CING: 3055 observations
# MURB: 4209 observations
# BADI: 1280 observations
#   1%|          | 7/594 [00:00<00:29, 20.05it/s]
# GRI: 675 observations
# RNI2: 834 observations
# MIDA: 926 observations
#   2%|▏         | 10/594 [00:00<00:29, 20.01it/s]
# VAGA: 844 observations
#   2%|▏         | 12/594 [00:00<00:29, 19.93it/s]
# INTR: 1812 observations
# GUAR: 590 observations
# FAGN: 3955 observations
#   3%|▎         | 16/594 [00:00<00:29, 19.75it/s]
# VVLD: 877 observations
#   3%|▎         | 18/594 [00:00<00:29, 19.77it/s]
# MRLC: 506 observations
# FIAM: 4520 observations
# MNS: 618 observations
# CERT: 1160 observations
#   4%|▎         | 21/594 [00:01<00:28, 19.98it/s]
# SFI: 1159 observations
# FNVD: 671 observations
#   4%|▍         | 24/594 [00:01<00:28, 20.08it/s]
# TIP: 577 observations
# TERO: 11019 observations
#   5%|▍         | 27/594 [00:01<00:28, 20.05it/s]
# AOI: 427 observations
# SACS: 571 observations
#   5%|▌         | 30/594 [00:01<00:28, 19.69it/s]
# CAMP: 3871 observations
# ERBM: 414 observations
# MRB1: 400 observations
#   6%|▌         | 34/594 [00:01<00:28, 19.78it/s]
# SACR: 430 observations
#   6%|▌         | 36/594 [00:01<00:28, 19.81it/s]
# BSSO: 568 observations
# CRE: 464 observations
#   7%|▋         | 39/594 [00:01<00:27, 19.93it/s]
# VLC: 1046 observations
#   7%|▋         | 42/594 [00:02<00:27, 19.95it/s]
# AQU: 5115 observations
# CEL: 862 observations
#   9%|▉         | 54/594 [00:02<00:26, 20.39it/s]
# CUC: 1667 observations
# GIB: 590 observations
# MGR: 712 observations
#  11%|█         | 66/594 [00:03<00:26, 20.18it/s]
# BDI: 1723 observations
# VULT: 400 observations
#  12%|█▏        | 72/594 [00:03<00:25, 20.14it/s]
# VCEL: 2776 observations
# ARVD: 2166 observations
# PLAC: 607 observations
#  13%|█▎        | 78/594 [00:03<00:25, 20.18it/s]
# CDRU: 480 observations
# ORI: 401 observations
# SERS: 634 observations
#  15%|█▍        | 87/594 [00:04<00:25, 20.04it/s]
# SCHR: 487 observations
# MSAG: 1061 observations
# SGRT: 705 observations
# OFFI: 1646 observations
#  16%|█▌        | 96/594 [00:04<00:24, 20.00it/s]
# CERA: 863 observations
# SIRI: 1483 observations
# MTSN: 499 observations
# JOPP: 1257 observations
#  17%|█▋        | 103/594 [00:05<00:24, 19.95it/s]
# MCEL: 799 observations
# GALF: 893 observations
# BULG: 488 observations
#  18%|█▊        | 109/594 [00:05<00:24, 19.92it/s]
# CRMI: 584 observations
# POFI: 925 observations
#  20%|█▉        | 118/594 [00:05<00:23, 20.02it/s]
# SSY: 874 observations
# MSRU: 844 observations
#  21%|██        | 125/594 [00:06<00:23, 19.93it/s]
# IVPL: 733 observations
# ACER: 482 observations
# ASQU: 625 observations
#  22%|██▏       | 132/594 [00:06<00:23, 19.98it/s]
# HAVL: 400 observations
# PIEI: 2442 observations
# CAFI: 1011 observations
# CDCA: 576 observations
# MILZ: 442 observations
#  24%|██▎       | 141/594 [00:07<00:22, 19.95it/s]
# FSSB: 1475 observations
# FDMO: 6690 observations
# CESI: 6033 observations
# LNSS: 6209 observations
#  25%|██▍       | 147/594 [00:07<00:22, 19.95it/s]
# MGAB: 2859 observations
# PARC: 871 observations
# MTCE: 476 observations
# LPEL: 1047 observations
#  26%|██▌       | 154/594 [00:07<00:22, 19.89it/s]
# MELA: 583 observations
#  27%|██▋       | 160/594 [00:07<00:21, 19.91it/s]
# CESX: 2443 observations
# ASSB: 2222 observations
# GUMA: 7527 observations
#  28%|██▊       | 168/594 [00:08<00:21, 19.85it/s]
# NRCA: 18010 observations
# ROVR: 534 observations
# MAIM: 408 observations
#  29%|██▉       | 174/594 [00:08<00:20, 20.15it/s]
# PZZ: 430 observations
#  31%|███       | 183/594 [00:09<00:20, 20.03it/s]
# T0104: 1986 observations
#  32%|███▏      | 189/594 [00:09<00:20, 20.19it/s]
# T0106: 439 observations
#  33%|███▎      | 195/594 [00:09<00:19, 20.26it/s]
# IACL: 492 observations
# MMN: 965 observations
# SMA1: 5503 observations
#  34%|███▍      | 201/594 [00:10<00:19, 20.08it/s]
# SALB: 1246 observations
# SNTG: 5397 observations
#  37%|███▋      | 222/594 [00:11<00:18, 20.10it/s]
# ATVO: 1560 observations
# ATPC: 932 observations
# ATFO: 1692 observations
# ATPI: 1312 observations
#  39%|███▊      | 230/594 [00:11<00:18, 19.82it/s]
# HLNI: 649 observations
# CAR1: 750 observations
# IFIL: 591 observations
#  40%|████      | 239/594 [00:11<00:17, 19.92it/s]
# NOV: 756 observations
# RM33: 8680 observations
#  41%|████      | 243/594 [00:12<00:17, 19.72it/s]
# FRON: 1901 observations
# MPNC: 798 observations
# SSFR: 5856 observations
# SLCN: 439 observations
# ATTE: 823 observations
#  43%|████▎     | 255/594 [00:12<00:17, 19.92it/s]
# MCSR: 636 observations
# PTQR: 400 observations
# MUCR: 802 observations
# CPGN: 593 observations
#  44%|████▍     | 262/594 [00:13<00:16, 19.94it/s]
# ATCC: 4133 observations
# POPM: 537 observations
#  45%|████▍     | 266/594 [00:13<00:16, 19.76it/s]
# MPAG: 1213 observations
#  46%|████▋     | 276/594 [00:13<00:17, 18.56it/s]
# CET2: 667 observations
# NARO: 760 observations
# SSP9: 609 observations
#  48%|████▊     | 285/594 [00:14<00:15, 19.64it/s]
# ATMI: 998 observations
# MDAR: 913 observations
# ARRO: 2425 observations
# SEF1: 1236 observations
#  49%|████▉     | 291/594 [00:14<00:15, 19.56it/s]
# FEMA: 4320 observations
#  53%|█████▎    | 315/594 [00:15<00:13, 20.34it/s]
# COR1: 563 observations
#  54%|█████▍    | 321/594 [00:16<00:13, 20.30it/s]
# FIU1: 504 observations
# MOMA: 2665 observations
#  56%|█████▌    | 330/594 [00:16<00:13, 19.94it/s]
# EL6: 4719 observations
# PE3: 695 observations
# CSP1: 6475 observations
#  57%|█████▋    | 336/594 [00:16<00:12, 20.01it/s]
# T0702: 624 observations
#  58%|█████▊    | 345/594 [00:17<00:12, 20.09it/s]
# AIO: 588 observations
# FOSV: 2719 observations
#  60%|█████▉    | 355/594 [00:17<00:11, 19.97it/s]
# GAG1: 533 observations
#  61%|██████    | 361/594 [00:18<00:11, 19.82it/s]
# RUFI: 853 observations
# MTCR: 955 observations
#  62%|██████▏   | 366/594 [00:18<00:11, 19.93it/s]
# SEI: 432 observations
# CARD: 445 observations
# ATLO: 575 observations
#  63%|██████▎   | 375/594 [00:18<00:10, 20.04it/s]
# OSSC: 420 observations
#  65%|██████▍   | 384/594 [00:19<00:10, 20.06it/s]
# MNTP: 704 observations
#  66%|██████▌   | 390/594 [00:19<00:10, 20.12it/s]
# PP3: 598 observations
#  69%|██████▉   | 411/594 [00:20<00:09, 20.02it/s]
# T0110: 798 observations
# ATSC: 595 observations
# GIGS: 907 observations
#  78%|███████▊  | 464/594 [00:23<00:06, 20.18it/s]
# MC2: 5765 observations
# T1211: 5386 observations
# T1243: 5407 observations
# MMO1: 4343 observations
# T1212: 5609 observations
# T1241: 4078 observations
# T1213: 2856 observations
#  79%|███████▉  | 470/594 [00:23<00:06, 20.22it/s]
# T1242: 1316 observations
# T1214: 4705 observations
# T1201: 1900 observations
# T1202: 2207 observations
# T1215: 8736 observations
# T1204: 2642 observations
# T1218: 8178 observations
#  80%|████████  | 476/594 [00:23<00:05, 20.08it/s]
# T1244: 3933 observations
# T1216: 11068 observations
# T1246: 1139 observations
#  81%|████████  | 482/594 [00:24<00:05, 20.17it/s]
# T1247: 1889 observations
# T1299: 6265 observations
# AM05: 2282 observations
# T1217: 6178 observations
# T1245: 6694 observations
#  83%|████████▎ | 491/594 [00:24<00:05, 20.26it/s]
# T1256: 3801 observations
# T1219: 7474 observations
# T1220: 4335 observations
# T1221: 4449 observations
#  84%|████████▎ | 497/594 [00:24<00:04, 20.15it/s]
# T1222: 1107 observations
#  86%|████████▌ | 509/594 [00:25<00:04, 19.92it/s]
# MTRA: 1422 observations
#  86%|████████▋ | 513/594 [00:25<00:04, 19.87it/s]
# MF5: 1011 observations
#  89%|████████▊ | 526/594 [00:26<00:03, 19.87it/s]
# PF6: 904 observations
#  91%|█████████ | 540/594 [00:27<00:02, 19.80it/s]
# MML1: 764 observations
#  93%|█████████▎| 555/594 [00:27<00:01, 20.05it/s]
# GAVE: 468 observations
# 100%|██████████| 594/594 [00:29<00:00, 20.00it/s]
# Number of stations with ≥400 observations: 169
# Number of records after multi-observations filtering: 362234
# Number of records after distance filtering (>28.07 km): 181141

# %% [markdown]
# Plot the histogram of the earthquake magnitudes after filtering

# %%
# Plot the histogram of the earthquake magnitudes after filtering
plt.figure(figsize=(10, 6))
sns.histplot(df_filtered["source_magnitude"], bins=30, kde=True, color='brown')
plt.xlabel('Magnitude', fontweight='bold', fontsize=14)
plt.ylabel('Number', fontweight='bold', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.grid(True)
max_magnitude = df_filtered["source_magnitude"].max()
min_magnitude = df_filtered["source_magnitude"].min()
plt.text(0.7*max_magnitude, plt.gca().get_ylim()[1]*0.8,
         f'Max: {max_magnitude:.2f} M\nMin: {min_magnitude:.2f} M',
         bbox=dict(facecolor='none', edgecolor='red', boxstyle='round,pad=1'), fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the histogram of the earthquake epicenter distance after filtering

# %%
# Plot the histogram of the earthquake epicenter distance (> 28.07 km) after filtering
plt.figure(figsize=(10, 6))
sns.histplot(df_filtered["path_ep_distance_km"], bins=30, kde=True, color='brown')
plt.xlabel('Epicenter Distance (km)', fontweight='bold', fontsize=14)
plt.ylabel('Number', fontweight='bold', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=14)
plt.grid(True)
max_distance = df_filtered["path_ep_distance_km"].max()
min_distance = df_filtered["path_ep_distance_km"].min()
plt.text(0.1*max_distance, plt.gca().get_ylim()[1]*0.8,
         f'Max: {max_distance:.2f} km\nMin: {min_distance:.2f} km',
         bbox=dict(facecolor='none', edgecolor='red', boxstyle='round,pad=1'), fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Cell 5: Group Seismograms by Events (KEY EVENT-BASED LOGIC)

# %%
"""Cell 5: Group Seismograms by Events (KEY ADAPTATION)"""

# Group seismograms by their source event ID (THIS IS THE KEY EVENT-BASED LOGIC)
print("Grouping seismograms by source event ID...")
event_to_seismograms = defaultdict(list)
seismogram_to_event = {}
event_metadata = {}

for index, row in df_filtered.iterrows():
    # Use source_id as the event identifier (adapt this if INSTANCE uses a different field)
    event_id = row['source_id'] if 'source_id' in row else row['source_event_id']  # Adapt field name as needed
    seismogram_id = row['trace_name']

    event_to_seismograms[event_id].append(seismogram_id)
    seismogram_to_event[seismogram_id] = event_id

    # Store metadata for each event (only once per event)
    if event_id not in event_metadata:
        event_metadata[event_id] = {
            'magnitude': row['source_magnitude'],
            'latitude': row['source_latitude_deg'], # Use correct column name for latitude: source_latitude_deg
            'longitude': row['source_longitude_deg'], # Use correct column name for longitude: source_longitude_deg
            'depth': row['source_depth_km'],
            'origin_time': row['source_origin_time']
        }

print(f"Number of unique earthquake events: {len(event_to_seismograms)}")
print(f"Average seismograms per event: {len(df_filtered) / len(event_to_seismograms):.2f}")

# Calculate the frequency of events with each number of seismograms
seismograms_per_event = [len(seismograms) for seismograms in event_to_seismograms.values()]

# Print summary statistics
print("\nDistribution statistics of seismograms per event:")
print(f"Minimum: {min(seismograms_per_event)} seismograms per event")
print(f"Maximum: {max(seismograms_per_event)} seismograms per event")

# Count frequency of each number of seismograms
counts = {}
for count in seismograms_per_event:
    counts[count] = counts.get(count, 0) + 1

# Output the counts
print("\nDetailed frequency distribution:")
for num_seismograms in range(1, min(21, max(seismograms_per_event) + 1)):  # Show up to 20 for readability
    num_events = counts.get(num_seismograms, 0)
    if num_events > 0:  # Only print non-zero counts to save space
        print(f"Number of events with {num_seismograms} seismogram{'s' if num_seismograms > 1 else ''}: {num_events}")

# Analyze the distribution of seismograms per event
seismograms_per_event = [len(seismograms) for seismograms in event_to_seismograms.values()]
plt.figure(figsize=(10, 6))
plt.hist(seismograms_per_event, bins=30)
plt.xlabel('Number of Seismograms per Event', fontweight='bold', fontsize=14)
plt.ylabel('Frequency', fontweight='bold', fontsize=14)
plt.title('Distribution of Seismograms per Earthquake Event', fontweight='bold', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Grouping seismograms by source event ID...
# Number of unique earthquake events: 22961
# Average seismograms per event: 7.89
#
# Distribution statistics of seismograms per event:
# Minimum: 1 seismograms per event
# Maximum: 82 seismograms per event
#
# Detailed frequency distribution:
# Number of events with 1 seismogram: 5365
# Number of events with 2 seismograms: 3176
# Number of events with 3 seismograms: 2070
# Number of events with 4 seismograms: 1636
# Number of events with 5 seismograms: 1293
# Number of events with 6 seismograms: 1072
# Number of events with 7 seismograms: 927
# Number of events with 8 seismograms: 781
# Number of events with 9 seismograms: 647
# Number of events with 10 seismograms: 553
# Number of events with 11 seismograms: 499
# Number of events with 12 seismograms: 467
# Number of events with 13 seismograms: 427
# Number of events with 14 seismograms: 365
# Number of events with 15 seismograms: 327
# Number of events with 16 seismograms: 290
# Number of events with 17 seismograms: 291
# Number of events with 18 seismograms: 241
# Number of events with 19 seismograms: 207
# Number of events with 20 seismograms: 183

# %% [markdown]
# Cell 6: Check Available Seismograms and Load Data

# %%
"""Cell 6: Check Available Seismograms and Load Data"""

# Check which seismograms exist in the HDF5 file
print("Checking available seismograms in HDF5 file...")

def explore_hdf5_structure(file_path):
    """Explore the HDF5 structure to understand data organization"""
    with h5py.File(file_path, 'r') as f:
        print("HDF5 structure:")
        f.visititems(lambda name, obj: print(f"  {name}: {type(obj)}"))

explore_hdf5_structure(hdf5_path)

# Get list of valid seismograms from the filtered metadata
valid_seismogram_ids = df_filtered['trace_name'].tolist()
print(f"Number of seismograms to load: {len(valid_seismogram_ids)}")

# Rebuild the event-to-seismograms mapping with only valid seismograms
valid_event_to_seismograms = defaultdict(list)
for seis_id in valid_seismogram_ids:
    event_id = seismogram_to_event[seis_id]
    valid_event_to_seismograms[event_id].append(seis_id)

# Remove events that have no valid seismograms left
valid_event_to_seismograms = {k: v for k, v in valid_event_to_seismograms.items() if len(v) > 0}
print(f"Number of events with valid seismograms: {len(valid_event_to_seismograms)}")

# Function to load seismogram data from HDF5 file (adapted for INSTANCE)
def load_seismogram_instance(hdf5_path, seismogram_id, metadata_row):
    """
    Load a single seismogram from the INSTANCE HDF5 file

    Args:
        hdf5_path: Path to the HDF5 file
        seismogram_id: ID of the seismogram to load (trace_name)
        metadata_row: Row from metadata containing trace information

    Returns:
        Tuple of (data, magnitude) or (None, None) if seismogram not found

    Notes:
        - Data is a 30-second window: 5s before P-arrival and 25s after
        - Resampled to 100Hz if necessary
    """
    try:
        with h5py.File(hdf5_path, 'r') as hdf:
            # Parse the trace name to get bucket and trace index
            bucket, trace_info = seismogram_id.split('$')
            trace_index = int(trace_info.split(',')[0])

            # Retrieve waveform data
            waveform = np.array(hdf['data'][bucket][trace_index])

            sampling_rate = metadata_row['trace_sampling_rate_hz']
            spt = int(metadata_row['trace_P_arrival_sample'])

            # Adjust window size based on sampling rate
            window_samples = int(30 * sampling_rate)  # 30 seconds window
            start = max(0, spt - int(5 * sampling_rate))  # 5 seconds before P arrival
            end = start + window_samples

            if start >= waveform.shape[1] or end > waveform.shape[1]:
                print(f"Skipping event {seismogram_id}: Invalid window")
                return None, None

            dshort = waveform[:, start:end]

            # Ensure the shape is correct
            if dshort.shape[1] != window_samples:
                print(f"Skipping event {seismogram_id}: Incorrect window size")
                return None, None

            # Resample to 100 Hz if necessary
            if sampling_rate != 100:
                dshort = scipy.signal.resample(dshort, 3000, axis=1)

            mag = round(float(metadata_row['source_magnitude']), 2)

            return dshort, mag

    except Exception as e:
        print(f"Error processing event {seismogram_id}: {e}")
        return None, None
# Out:
# Checking available seismograms in HDF5 file...
# HDF5 structure:
#   data: <class 'h5py._hl.group.Group'>
#   data/bucket0: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket10: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket100: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1000: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1001: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1002: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1003: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1004: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1005: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1006: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1007: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1008: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1009: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket101: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1010: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1011: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1012: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1013: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1014: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1015: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1016: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1017: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1018: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1019: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket102: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1020: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1021: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1022: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1023: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1024: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1025: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1026: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1027: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1028: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1029: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket103: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1030: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1031: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1032: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1033: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1034: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1035: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1036: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1037: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1038: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1039: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket104: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1040: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1041: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1042: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1043: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1044: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1045: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1046: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1047: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1048: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1049: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket105: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1050: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1051: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1052: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1053: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1054: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1055: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1056: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1057: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1058: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1059: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket106: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1060: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1061: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1062: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1063: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1064: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1065: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1066: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1067: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1068: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1069: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket107: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1070: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1071: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1072: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1073: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1074: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1075: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1076: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1077: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1078: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1079: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket108: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1080: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1081: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1082: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1083: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1084: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1085: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1086: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1087: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1088: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1089: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket109: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1090: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1091: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1092: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1093: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1094: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1095: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1096: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1097: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1098: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1099: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket11: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket110: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1100: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1101: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1102: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1103: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1104: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1105: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1106: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1107: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1108: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1109: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket111: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1110: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1111: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1112: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1113: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1114: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1115: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1116: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1117: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1118: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1119: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket112: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1120: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1121: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1122: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1123: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1124: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1125: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1126: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1127: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1128: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1129: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket113: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1130: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1131: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1132: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket1133: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket114: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket115: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket116: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket117: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket118: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket119: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket12: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket120: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket121: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket122: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket123: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket124: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket125: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket126: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket127: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket128: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket129: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket13: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket130: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket131: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket132: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket133: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket134: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket135: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket136: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket137: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket138: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket139: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket14: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket140: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket141: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket142: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket143: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket144: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket145: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket146: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket147: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket148: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket149: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket15: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket150: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket151: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket152: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket153: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket154: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket155: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket156: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket157: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket158: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket159: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket16: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket160: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket161: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket162: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket163: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket164: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket165: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket166: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket167: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket168: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket169: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket17: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket170: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket171: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket172: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket173: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket174: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket175: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket176: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket177: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket178: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket179: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket18: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket180: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket181: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket182: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket183: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket184: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket185: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket186: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket187: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket188: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket189: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket19: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket190: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket191: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket192: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket193: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket194: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket195: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket196: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket197: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket198: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket199: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket2: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket20: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket200: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket201: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket202: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket203: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket204: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket205: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket206: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket207: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket208: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket209: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket21: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket210: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket211: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket212: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket213: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket214: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket215: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket216: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket217: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket218: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket219: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket22: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket220: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket221: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket222: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket223: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket224: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket225: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket226: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket227: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket228: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket229: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket23: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket230: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket231: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket232: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket233: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket234: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket235: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket236: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket237: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket238: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket239: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket24: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket240: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket241: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket242: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket243: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket244: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket245: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket246: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket247: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket248: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket249: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket25: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket250: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket251: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket252: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket253: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket254: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket255: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket256: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket257: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket258: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket259: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket26: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket260: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket261: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket262: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket263: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket264: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket265: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket266: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket267: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket268: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket269: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket27: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket270: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket271: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket272: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket273: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket274: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket275: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket276: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket277: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket278: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket279: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket28: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket280: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket281: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket282: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket283: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket284: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket285: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket286: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket287: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket288: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket289: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket29: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket290: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket291: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket292: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket293: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket294: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket295: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket296: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket297: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket298: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket299: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket3: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket30: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket300: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket301: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket302: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket303: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket304: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket305: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket306: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket307: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket308: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket309: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket31: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket310: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket311: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket312: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket313: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket314: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket315: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket316: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket317: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket318: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket319: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket32: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket320: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket321: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket322: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket323: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket324: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket325: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket326: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket327: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket328: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket329: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket33: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket330: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket331: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket332: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket333: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket334: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket335: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket336: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket337: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket338: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket339: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket34: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket340: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket341: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket342: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket343: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket344: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket345: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket346: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket347: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket348: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket349: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket35: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket350: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket351: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket352: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket353: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket354: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket355: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket356: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket357: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket358: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket359: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket36: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket360: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket361: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket362: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket363: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket364: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket365: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket366: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket367: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket368: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket369: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket37: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket370: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket371: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket372: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket373: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket374: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket375: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket376: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket377: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket378: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket379: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket38: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket380: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket381: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket382: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket383: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket384: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket385: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket386: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket387: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket388: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket389: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket39: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket390: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket391: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket392: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket393: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket394: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket395: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket396: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket397: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket398: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket399: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket4: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket40: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket400: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket401: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket402: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket403: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket404: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket405: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket406: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket407: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket408: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket409: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket41: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket410: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket411: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket412: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket413: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket414: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket415: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket416: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket417: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket418: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket419: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket42: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket420: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket421: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket422: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket423: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket424: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket425: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket426: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket427: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket428: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket429: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket43: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket430: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket431: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket432: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket433: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket434: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket435: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket436: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket437: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket438: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket439: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket44: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket440: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket441: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket442: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket443: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket444: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket445: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket446: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket447: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket448: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket449: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket45: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket450: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket451: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket452: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket453: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket454: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket455: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket456: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket457: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket458: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket459: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket46: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket460: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket461: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket462: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket463: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket464: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket465: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket466: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket467: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket468: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket469: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket47: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket470: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket471: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket472: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket473: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket474: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket475: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket476: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket477: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket478: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket479: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket48: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket480: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket481: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket482: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket483: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket484: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket485: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket486: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket487: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket488: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket489: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket49: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket490: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket491: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket492: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket493: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket494: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket495: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket496: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket497: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket498: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket499: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket5: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket50: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket500: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket501: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket502: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket503: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket504: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket505: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket506: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket507: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket508: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket509: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket51: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket510: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket511: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket512: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket513: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket514: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket515: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket516: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket517: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket518: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket519: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket52: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket520: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket521: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket522: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket523: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket524: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket525: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket526: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket527: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket528: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket529: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket53: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket530: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket531: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket532: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket533: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket534: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket535: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket536: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket537: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket538: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket539: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket54: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket540: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket541: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket542: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket543: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket544: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket545: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket546: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket547: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket548: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket549: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket55: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket550: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket551: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket552: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket553: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket554: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket555: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket556: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket557: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket558: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket559: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket56: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket560: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket561: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket562: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket563: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket564: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket565: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket566: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket567: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket568: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket569: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket57: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket570: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket571: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket572: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket573: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket574: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket575: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket576: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket577: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket578: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket579: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket58: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket580: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket581: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket582: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket583: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket584: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket585: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket586: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket587: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket588: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket589: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket59: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket590: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket591: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket592: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket593: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket594: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket595: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket596: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket597: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket598: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket599: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket6: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket60: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket600: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket601: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket602: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket603: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket604: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket605: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket606: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket607: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket608: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket609: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket61: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket610: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket611: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket612: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket613: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket614: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket615: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket616: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket617: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket618: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket619: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket62: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket620: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket621: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket622: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket623: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket624: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket625: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket626: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket627: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket628: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket629: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket63: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket630: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket631: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket632: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket633: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket634: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket635: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket636: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket637: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket638: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket639: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket64: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket640: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket641: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket642: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket643: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket644: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket645: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket646: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket647: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket648: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket649: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket65: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket650: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket651: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket652: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket653: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket654: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket655: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket656: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket657: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket658: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket659: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket66: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket660: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket661: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket662: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket663: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket664: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket665: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket666: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket667: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket668: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket669: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket67: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket670: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket671: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket672: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket673: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket674: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket675: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket676: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket677: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket678: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket679: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket68: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket680: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket681: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket682: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket683: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket684: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket685: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket686: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket687: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket688: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket689: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket69: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket690: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket691: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket692: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket693: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket694: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket695: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket696: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket697: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket698: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket699: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket7: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket70: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket700: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket701: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket702: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket703: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket704: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket705: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket706: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket707: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket708: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket709: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket71: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket710: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket711: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket712: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket713: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket714: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket715: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket716: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket717: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket718: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket719: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket72: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket720: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket721: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket722: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket723: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket724: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket725: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket726: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket727: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket728: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket729: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket73: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket730: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket731: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket732: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket733: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket734: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket735: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket736: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket737: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket738: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket739: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket74: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket740: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket741: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket742: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket743: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket744: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket745: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket746: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket747: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket748: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket749: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket75: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket750: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket751: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket752: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket753: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket754: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket755: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket756: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket757: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket758: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket759: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket76: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket760: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket761: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket762: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket763: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket764: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket765: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket766: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket767: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket768: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket769: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket77: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket770: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket771: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket772: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket773: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket774: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket775: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket776: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket777: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket778: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket779: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket78: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket780: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket781: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket782: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket783: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket784: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket785: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket786: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket787: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket788: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket789: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket79: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket790: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket791: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket792: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket793: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket794: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket795: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket796: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket797: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket798: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket799: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket8: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket80: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket800: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket801: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket802: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket803: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket804: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket805: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket806: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket807: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket808: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket809: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket81: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket810: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket811: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket812: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket813: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket814: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket815: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket816: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket817: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket818: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket819: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket82: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket820: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket821: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket822: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket823: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket824: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket825: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket826: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket827: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket828: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket829: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket83: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket830: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket831: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket832: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket833: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket834: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket835: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket836: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket837: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket838: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket839: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket84: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket840: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket841: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket842: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket843: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket844: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket845: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket846: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket847: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket848: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket849: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket85: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket850: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket851: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket852: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket853: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket854: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket855: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket856: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket857: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket858: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket859: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket86: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket860: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket861: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket862: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket863: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket864: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket865: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket866: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket867: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket868: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket869: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket87: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket870: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket871: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket872: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket873: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket874: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket875: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket876: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket877: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket878: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket879: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket88: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket880: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket881: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket882: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket883: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket884: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket885: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket886: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket887: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket888: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket889: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket89: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket890: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket891: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket892: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket893: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket894: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket895: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket896: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket897: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket898: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket899: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket9: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket90: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket900: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket901: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket902: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket903: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket904: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket905: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket906: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket907: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket908: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket909: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket91: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket910: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket911: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket912: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket913: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket914: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket915: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket916: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket917: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket918: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket919: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket92: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket920: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket921: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket922: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket923: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket924: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket925: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket926: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket927: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket928: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket929: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket93: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket930: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket931: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket932: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket933: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket934: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket935: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket936: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket937: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket938: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket939: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket94: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket940: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket941: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket942: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket943: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket944: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket945: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket946: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket947: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket948: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket949: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket95: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket950: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket951: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket952: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket953: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket954: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket955: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket956: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket957: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket958: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket959: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket96: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket960: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket961: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket962: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket963: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket964: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket965: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket966: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket967: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket968: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket969: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket97: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket970: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket971: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket972: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket973: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket974: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket975: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket976: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket977: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket978: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket979: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket98: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket980: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket981: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket982: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket983: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket984: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket985: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket986: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket987: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket988: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket989: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket99: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket990: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket991: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket992: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket993: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket994: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket995: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket996: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket997: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket998: <class 'h5py._hl.dataset.Dataset'>
#   data/bucket999: <class 'h5py._hl.dataset.Dataset'>
#   data_format: <class 'h5py._hl.group.Group'>
#   data_format/component_order: <class 'h5py._hl.dataset.Dataset'>
#   data_format/dimension_order: <class 'h5py._hl.dataset.Dataset'>
#   data_format/instrument_response: <class 'h5py._hl.dataset.Dataset'>
#   data_format/measurement: <class 'h5py._hl.dataset.Dataset'>
#   data_format/unit: <class 'h5py._hl.dataset.Dataset'>
# Number of seismograms to load: 181141
# Number of events with valid seismograms: 22961

# %% [markdown]
# Cell 7: Load All Valid Seismograms and Create Event Data

# %%
"""Cell 7: Load All Valid Seismograms and Create Event Data"""

# Load all valid seismograms
print("Loading all valid seismograms...")
all_data = []
all_labels = []
all_event_ids = []  # To track which event each seismogram belongs to
all_seismogram_ids = []  # To track the original seismogram ID

# Event data dict to store waveforms by event
event_waveform_data = {}

# Create a lookup dictionary for metadata rows
metadata_lookup = {row['trace_name']: row for _, row in df_filtered.iterrows()}

for event_id, seismogram_ids in tqdm(valid_event_to_seismograms.items(), desc="Loading events"):
    event_waveforms = []

    for seis_id in seismogram_ids:
        if seis_id not in metadata_lookup:
            continue

        metadata_row = metadata_lookup[seis_id]
        data, label = load_seismogram_instance(hdf5_path, seis_id, metadata_row)

        if data is None:
            continue

        all_data.append(data)
        all_labels.append(label)
        all_event_ids.append(event_id)
        all_seismogram_ids.append(seis_id)

        # Store for event visualization
        event_waveforms.append({
            'data': data,
            'magnitude': label,
            'seismogram_id': seis_id
        })

    if event_waveforms:  # Only store events that have valid waveforms
        event_waveform_data[event_id] = event_waveforms

# Convert lists to numpy arrays
all_data = np.array(all_data)
all_labels = np.array(all_labels)
all_event_ids = np.array(all_event_ids)
all_seismogram_ids = np.array(all_seismogram_ids)

print(f"Final dataset: {len(all_data)} seismograms from {len(np.unique(all_event_ids))} events")
print(f"Data shape: {all_data.shape}, Labels shape: {all_labels.shape}")

# Save the mapping between seismogram indices and their IDs
with open(os.path.join(output_dir, 'seismogram_indices.pkl'), 'wb') as f:
    pickle.dump({
        'seismogram_ids': all_seismogram_ids,
        'event_ids': all_event_ids
    }, f)
# Out:
# Loading all valid seismograms...
# Loading events: 100%|██████████| 22961/22961 [08:27<00:00, 45.23it/s]
# Final dataset: 181141 seismograms from 22961 events
# Data shape: (181141, 3, 3000), Labels shape: (181141,)

# %% [markdown]
# Cell 8: Visualize Example Events

# %%
"""Cell 8: Visualize Example Events"""

# Visualize example events showing all seismograms from the same event
# Find events with multiple seismograms for visualization
events_with_multiple_seismograms = []
for event_id, waveforms in event_waveform_data.items():
    if len(waveforms) > 1:
        events_with_multiple_seismograms.append((event_id, len(waveforms)))

# Sort by number of seismograms (descending)
events_with_multiple_seismograms.sort(key=lambda x: x[1], reverse=True)

# Function to visualize all seismograms from an event
def visualize_event_seismograms_instance(event_id, max_seismograms=6):
    """
    Visualize all seismograms from a specific event to show event grouping

    Args:
        event_id: ID of the event to visualize
        max_seismograms: Maximum number of seismograms to display
    """
    waveforms = event_waveform_data[event_id]
    event_info = event_metadata.get(event_id, {})

    # Limit the number of seismograms to display
    num_seismograms = min(len(waveforms), max_seismograms)
    waveforms = waveforms[:num_seismograms]

    # Create a figure with subplots for each seismogram (3 components each)
    fig = plt.figure(figsize=(15, num_seismograms * 5))
    fig.suptitle(f"Event ID: {event_id}\nMagnitude: {event_info.get('magnitude', 'N/A')}, "
                f"Depth: {event_info.get('depth', 'N/A')} km\n"
                f"Location: ({event_info.get('latitude', 'N/A')}, {event_info.get('longitude', 'N/A')})\n"
                f"Total Seismograms: {len(event_waveform_data[event_id])}",
                fontsize=16, fontweight='bold')

    components = ['East-West', 'North-South', 'Vertical']
    time = np.arange(3000) / 100  # Convert to seconds (100Hz sampling)

    for i, waveform in enumerate(waveforms):
        data = waveform['data']
        seis_id = waveform['seismogram_id']

        for j in range(3):
            ax = fig.add_subplot(num_seismograms, 3, i*3 + j + 1)
            ax.plot(time, data[j, :], 'k')

            ax.set_title(f"Seismogram {i+1} - {components[j]}")
            ax.set_xlabel('Time (seconds)')
            ax.set_ylabel('Amplitude')
            ax.axvline(x=5.0, color='blue', linestyle='--', linewidth=1, label='P-arrival')
            ax.grid(True)

            # Only add legend to the first subplot
            if i == 0 and j == 0:
                ax.legend()

            # Add seismogram ID as a text annotation
            if j == 2:  # Add to the vertical component only
                ax.annotate(f"ID: {seis_id}", xy=(0.5, -0.4), xycoords='axes fraction',
                            fontsize=10, ha='center')

    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust for the suptitle
    plt.savefig(os.path.join(output_dir, f'event_{event_id}_seismograms.png'), dpi=150)
    plt.show()

# Visualize a few events with multiple seismograms
print("\nVisualizing example events with multiple seismograms:")
for i, (event_id, count) in enumerate(events_with_multiple_seismograms[:3]):
    print(f"Example {i+1}: Event {event_id} with {count} seismograms")
    visualize_event_seismograms_instance(event_id)

# Plot an example single seismogram
def plot_example_seismogram_instance(data, index=0):
    """Plot an example three-component seismogram"""
    fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)
    time = np.arange(data.shape[2]) / 100  # Convert to seconds (100Hz sampling)
    components = ['East-West', 'North-South', 'Vertical']

    for i in range(3):
        axes[i].plot(time, data[index, i, :], 'k')
        axes[i].set_ylabel(f'{components[i]}\nAmplitude', fontweight='bold', fontsize=14)
        axes[i].axvline(x=5.0, color='blue', linestyle='--', linewidth=2,
                      label='P-arrival (5s mark)')
        axes[i].grid(True)
        axes[i].legend(fontsize=12)

    axes[2].set_xlabel('Time (seconds)', fontweight='bold', fontsize=14)
    plt.suptitle(f'Example INSTANCE Seismogram (Magnitude: {all_labels[index]})',
                fontweight='bold', fontsize=16)
    plt.tight_layout()
    plt.show()

# Plot an example seismogram
if len(all_data) > 0:
    plot_example_seismogram_instance(all_data)
# Out:
# Visualizing example events with multiple seismograms:
# Example 1: Event 10701061 with 82 seismograms
# Example 2: Event 11535771 with 82 seismograms
# Example 3: Event 10737031 with 78 seismograms

# %% [markdown]
# Cell 9: Save Data and Create Split Information

# %%
"""Cell 9: Save Data and Create Split Information"""

# Convert to tensors
all_data_tensor = torch.tensor(all_data, dtype=torch.float32)
all_labels_tensor = torch.tensor(all_labels, dtype=torch.float32)

# Save the entire dataset and associated event IDs
print("Saving data files...")
torch.save(all_data_tensor, os.path.join(output_dir, 'all_data.pt'))
torch.save(all_labels_tensor, os.path.join(output_dir, 'all_labels.pt'))

# Save the mapping between indices and event IDs for future reference
with open(os.path.join(output_dir, 'index_to_event_id.pkl'), 'wb') as f:
    pickle.dump({
        'all_event_ids': all_event_ids,
        'event_to_seismograms': valid_event_to_seismograms,
        'event_metadata': event_metadata
    }, f)

# Create function to generate the splits file without using seeds
# This file will be used by the second notebook which will apply its own seeds
def generate_event_based_split_indices(all_event_ids, train_ratio=0.7, val_ratio=0.1):
    """
    Generate the splits file without applying any shuffling
    The second notebook will handle the randomization with specific seeds

    Args:
        all_event_ids: Array of event IDs corresponding to each seismogram
        train_ratio: Proportion for training set
        val_ratio: Proportion for validation set

    Returns:
        Dictionary with unique events and their corresponding seismogram indices
    """
    # Get unique event IDs (maintaining order)
    unique_events = []
    for event_id in all_event_ids:
        if event_id not in unique_events:
            unique_events.append(event_id)

    unique_events = np.array(unique_events)
    print(f"Found {len(unique_events)} unique events for split preparation")

    # Get the indices for each event
    event_indices = {}
    for event_id in unique_events:
        indices = np.where(all_event_ids == event_id)[0]
        event_indices[event_id] = indices

    return {
        'unique_events': unique_events,
        'event_indices': event_indices,
        'train_ratio': train_ratio,
        'val_ratio': val_ratio
    }

# Generate the splits file (without applying randomization)
print("Preparing split information for second notebook...")
split_info = generate_event_based_split_indices(all_event_ids)

# Save the split information
with open(os.path.join(output_dir, 'event_split_info.pkl'), 'wb') as f:
    pickle.dump(split_info, f)
# Out:
# Saving data files...
# Preparing split information for second notebook...
# Found 22961 unique events for split preparation

# %% [markdown]
# Cell 10: Summary and Final Statistics

# %%
"""Cell 10: Summary and Final Statistics"""

# Print a summary of what was created
print("\nFiles created in the output directory:")
print(f"1. all_data.pt - All seismogram data tensors")
print(f"2. all_labels.pt - All magnitude labels")
print(f"3. index_to_event_id.pkl - Mapping between indices and event IDs")
print(f"4. event_split_info.pkl - Information for creating random event-based splits")
print(f"5. multi_observations.npy - List of stations with ≥400 observations")
print(f"6. seismogram_indices.pkl - Mapping between indices and seismogram IDs")
print(f"7. Event visualization images (PNG files)")

# Print statistics about the event distribution
seismograms_per_event = [len(event_waveform_data[event_id]) for event_id in event_waveform_data.keys()]
print(f"\nEvent Distribution Statistics:")
print(f"Total events: {len(event_waveform_data)}")
print(f"Total seismograms: {len(all_data)}")
print(f"Average seismograms per event: {np.mean(seismograms_per_event):.2f}")
print(f"Median seismograms per event: {np.median(seismograms_per_event):.0f}")
print(f"Max seismograms per event: {max(seismograms_per_event)}")
print(f"Min seismograms per event: {min(seismograms_per_event)}")

# Print example events for reference
print("\nExample events with multiple seismograms:")
for i, (event_id, count) in enumerate(events_with_multiple_seismograms[:10]):
    print(f"Event {event_id}: {count} seismograms")

# Report execution time
end_time = time.time()
print(f"\nTotal execution time: {(end_time - start_time) / 60:.2f} minutes")

print("\nPreprocessing complete! Now you can run the 50 experiments notebook using the same logic as STEAD.")
print("\nKey differences from STEAD:")
print(f"- INSTANCE average seismograms per event: {np.mean(seismograms_per_event):.2f}")
print(f"- STEAD average seismograms per event: 2.14")
print(f"- INSTANCE may show more pronounced differences between event-based and seismogram-based splitting")

print("\nINSTANCE event-based preprocessing completed successfully!")
print("Used SeisBench download - no Google Drive quota issues!")
# Out:
# Files created in the output directory:
# 1. all_data.pt - All seismogram data tensors
# 2. all_labels.pt - All magnitude labels
# 3. index_to_event_id.pkl - Mapping between indices and event IDs
# 4. event_split_info.pkl - Information for creating random event-based splits
# 5. multi_observations.npy - List of stations with ≥400 observations
# 6. seismogram_indices.pkl - Mapping between indices and seismogram IDs
# 7. Event visualization images (PNG files)
#
# Event Distribution Statistics:
# Total events: 22961
# Total seismograms: 181141
# Average seismograms per event: 7.89
# Median seismograms per event: 4
# Max seismograms per event: 82
# Min seismograms per event: 1
#
# Example events with multiple seismograms:
# Event 10701061: 82 seismograms
# Event 11535771: 82 seismograms
# Event 10737031: 78 seismograms
# Event 11535691: 77 seismograms
# Event 7213271: 73 seismograms
# Event 9070811: 73 seismograms
# Event 9533371: 73 seismograms
# Event 10423461: 73 seismograms
# Event 10573681: 73 seismograms
# Event 11438671: 73 seismograms
#
# Total execution time: 115.99 minutes
#
# Preprocessing complete! Now you can run the 50 experiments notebook using the same logic as STEAD.
#
# Key differences from STEAD:
# - INSTANCE average seismograms per event: 7.89
# - STEAD average seismograms per event: 2.14
# - INSTANCE may show more pronounced differences between event-based and seismogram-based splitting
#
# INSTANCE event-based preprocessing completed successfully!
# Used SeisBench download - no Google Drive quota issues!
